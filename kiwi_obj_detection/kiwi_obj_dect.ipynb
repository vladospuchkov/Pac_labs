# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.2/716.2 kB 9.9 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi
# Out:
# Wed Feb 21 13:35:15 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ujvHd2Xsm5BdgV3XNTYG")
project = rf.workspace("firsttaskpac2sem").project("kiwi_object_detection")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
# ...

# %%
from ultralytics import YOLO
madel = YOLO('yolov8n.yaml')
model = YOLO('yolov8n.pt')

results = model.train(data='/content/kiwi_object_detection-1/data.yaml', epochs=20, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 117MB/s]
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
res = model('https://icdn.lenta.ru/images/2023/08/06/15/20230806152257201/wide_16_9_cbbcbdbd6e9e64a01b9147a5a89f642c.jpg', save=True)
# Out:
# ...
# 100%|██████████| 88.5k/88.5k [00:00<00:00, 543kB/s]
# image 1/1 /content/wide_16_9_cbbcbdbd6e9e64a01b9147a5a89f642c.jpg: 384x640 1 kiwi_AA, 91.8ms
# Speed: 1.6ms preprocess, 91.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train2

# %%
res = model('https://gagaru.club/uploads/posts/2023-05/1685174336_gagaru-club-p-kivi-razrezannii-6.png', save=True)
# Out:
# ...
# 100%|██████████| 1.09M/1.09M [00:00<00:00, 1.29MB/s]
# image 1/1 /content/1685174336_gagaru-club-p-kivi-razrezannii-6.png: 448x640 8 kiwi_AAs, 14.1ms
# Speed: 3.7ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/train45
